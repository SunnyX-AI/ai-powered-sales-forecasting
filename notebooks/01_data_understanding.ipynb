# %%
pd.set_option ('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# -----------------------------------
# Supabase owner/admin connection
# -----------------------------------
host = "db.ogkdfmkybqtrsglcizzt.supabase.co"   # direct host
port = 5432
database = "postgres"
user = "postgres"
password = quote_plus("Bonabosssfs01")   # replace with your real password

engine = create_engine(
    f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}?sslmode=require",
    pool_pre_ping=True
)

# -----------------------------------
# Example extraction
# -----------------------------------
df_sales = pd.read_sql("""
SELECT *
FROM core.fact_sales
ORDER BY date ASC
""", engine)

# %%
import pandas as pd

# -------------------------
# DIM TABLES
# -------------------------

df_calendar = pd.read_sql("""
SELECT * FROM core.dim_calendar
ORDER BY date ASC
""", engine)

df_policy_regimes = pd.read_sql("""
SELECT * FROM core.dim_policy_regimes
ORDER BY start_date ASC
""", engine)

df_products = pd.read_sql("""
SELECT * FROM core.dim_products
ORDER BY product_id ASC
""", engine)

df_stores = pd.read_sql("""
SELECT * FROM core.dim_stores
ORDER BY store_id ASC
""", engine)


# -------------------------
# FACT TABLES
# -------------------------

df_sales = pd.read_sql("""
SELECT * FROM core.fact_sales
ORDER BY date ASC
""", engine)

df_inventory = pd.read_sql("""
SELECT * FROM core.fact_inventory
ORDER BY date ASC
""", engine)

df_customer_activity = pd.read_sql("""
SELECT * FROM core.fact_customer_activity
ORDER BY date ASC
""", engine)

df_store_operations = pd.read_sql("""
SELECT * FROM core.fact_store_operations
ORDER BY date ASC
""", engine)

df_promotions = pd.read_sql("""
SELECT * FROM core.fact_promotions
ORDER BY date ASC
""", engine)

df_restrictions = pd.read_sql("""
SELECT * FROM core.fact_restriction_events
ORDER BY date ASC
""", engine)

df_weather = pd.read_sql("""
SELECT * FROM core.fact_weather
ORDER BY date ASC
""", engine)

# %%
df_sales.head()
# Out:
#          date  store_id  product_id  units_sold     price  regular_price  \
# 0  2021-01-01         1        1070           0   64012.0          64012
# 1  2021-01-01         1        1069           0  462942.0         462942
# 2  2021-01-01         1        1068           6  338093.0         338093
# 3  2021-01-01         1        1067           2   99634.0          99634
# 4  2021-01-01         1        1066           3   52233.0          52233
#
#    discount_pct  promo_flag promo_type    revenue  starting_inventory  \
# 0             0           0       None        0.0                   0
# 1             0           0       None        0.0                   0
# 2             0           0       None  2028558.0                  11
# 3             0           0       None   199268.0                   7
# 4             0           0       None   156699.0                   4
#
#    restock_qty  ending_inventory  stockout_occurred  restriction_active  \
# 0            0                 0                  1                   0
# 1            0                 0                  1                   0
# 2            0                 5                  0                   0
# 3            0                 5                  0                   0
# 4            0                 1                  0                   0
#
#   restriction_type   city store_size store_type          category
# 0             None  Benin      Large       Mall  Small Appliances
# 1             None  Benin      Large       Mall     Mobile Phones
# 2             None  Benin      Large       Mall     Mobile Phones
# 3             None  Benin      Large       Mall   Network Devices
# 4             None  Benin      Large       Mall  Small Appliances

# %%
df_sales.columns
# Out:
# Index(['date', 'store_id', 'product_id', 'units_sold', 'price',
#        'regular_price', 'discount_pct', 'promo_flag', 'promo_type', 'revenue',
#        'starting_inventory', 'restock_qty', 'ending_inventory',
#        'stockout_occurred', 'restriction_active', 'restriction_type', 'city',
#        'store_size', 'store_type', 'category'],
#       dtype='object')

# %%
df_sales.store_type.unique()
# Out:
# array(['Mall', 'High Street', 'Plaza'], dtype=object)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1618680 entries, 0 to 1618679
# Data columns (total 20 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   date                1618680 non-null  object
#  1   store_id            1618680 non-null  int64
#  2   product_id          1618680 non-null  int64
#  3   units_sold          1618680 non-null  int64
#  4   price               1618680 non-null  float64
#  5   regular_price       1618680 non-null  int64
#  6   discount_pct        1618680 non-null  int64
#  7   promo_flag          1618680 non-null  int64
#  8   promo_type          225 non-null      object
#  9   revenue             1618680 non-null  float64
#  10  starting_inventory  1618680 non-null  int64
#  11  restock_qty         1618680 non-null  int64
#  12  ending_inventory    1618680 non-null  int64
#  13  stockout_occurred   1618680 non-null  int64
#  14  restriction_active  1618680 non-null  int64
#  15  restriction_type    435478 non-null   object
#  16  city                1618680 non-null  object
#  17  store_size          1618680 non-null  object
#  18  store_type          1618680 non-null  object
#  19  category            1618680 non-null  object
# dtypes: float64(2), int64(11), object(7)
# memory usage: 247.0+ MB

# %%
df_products.shape
# Out:
# (120, 8)

# %%
df_policy_regimes
# Out:
#     policy_id                                policy_name           start_date  \
# 0           1                       Mall Expansion Drive  2021-04-10 00:00:00
# 1           3              Small Store Inventory Control  2022-01-11 00:00:00
# 2           2              Small Store Inventory Control           2022-11-06
# 3           2                      Telecom Seasonal Push  2024-11-09 00:00:00
# 4           1  Cooling Appliances Availability Programme           2024-11-19
# 5           4  Cooling Appliances Availability Programme  2025-07-09 00:00:00
# 6           3                      Telecom Seasonal Push           2025-09-10
# 7           4      Premium Electronics Margin Protection           2025-09-30
# 8           3  Cooling Appliances Availability Programme  2026-04-08 00:00:00
# 9           1                      Telecom Seasonal Push  2026-04-10 00:00:00
# 10          2      Premium Electronics Margin Protection  2026-04-10 00:00:00
# 11          4                       Mall Expansion Drive  2026-04-10 00:00:00
#
#                end_date affected_category affected_store_type  \
# 0   2021-12-04 00:00:00              None                Mall
# 1   2022-07-21 00:00:00              None               Plaza
# 2            2023-05-19              None               Plaza
# 3   2025-06-25 00:00:00  Telecom Services                None
# 4            2025-05-08  Air Conditioners                None
# 5   2025-10-20 00:00:00  Air Conditioners                None
# 6            2026-04-06  Telecom Services                None
# 7            2026-04-06     Mobile Phones                None
# 8   2026-04-11 00:00:00  Air Conditioners                None
# 9   2026-04-11 00:00:00  Telecom Services                None
# 10  2026-04-11 00:00:00     Mobile Phones                None
# 11  2026-04-11 00:00:00              None                Mall
#
#     demand_multiplier  discount_cap_pct  replenishment_multiplier  \
# 0                1.08                25                      1.12
# 1                0.98                15                      0.88
# 2                0.98                15                      0.88
# 3                1.15                20                      1.10
# 4                1.10                20                      1.20
# 5                1.10                20                      1.20
# 6                1.15                20                      1.10
# 7                0.96                10                      0.95
# 8                1.10                20                      1.20
# 9                1.15                20                      1.10
# 10               0.96                10                      0.95
# 11               1.08                25                      1.12
#
#     service_intensity_multiplier
# 0                           1.10
# 1                           1.00
# 2                           1.00
# 3                           1.08
# 4                           1.05
# 5                           1.05
# 6                           1.08
# 7                           1.02
# 8                           1.05
# 9                           1.08
# 10                          1.02
# 11                          1.10

# %%
print(df_sales.head())
# Out:
#          date  store_id  product_id  units_sold     price  regular_price  \
# 0  2021-01-01         1        1070           0   64012.0          64012
# 1  2021-01-01         1        1069           0  462942.0         462942
# 2  2021-01-01         1        1068           6  338093.0         338093
# 3  2021-01-01         1        1067           2   99634.0          99634
# 4  2021-01-01         1        1066           3   52233.0          52233
#
#    discount_pct  promo_flag promo_type    revenue  starting_inventory  \
# 0             0           0       None        0.0                   0
# 1             0           0       None        0.0                   0
# 2             0           0       None  2028558.0                  11
# 3             0           0       None   199268.0                   7
# 4             0           0       None   156699.0                   4
#
#    restock_qty  ending_inventory  stockout_occurred  restriction_active  \
# 0            0                 0                  1                   0
# 1            0                 0                  1                   0
# 2            0                 5                  0                   0
# 3            0                 5                  0                   0
# 4            0                 1                  0                   0
#
#   restriction_type   city store_size store_type          category
# 0             None  Benin      Large       Mall  Small Appliances
# 1             None  Benin      Large       Mall     Mobile Phones
# 2             None  Benin      Large       Mall     Mobile Phones
# 3             None  Benin      Large       Mall   Network Devices
# 4             None  Benin      Large       Mall  Small Appliances

# %%
df['store_id'].nunique()
# Out:
# 7

# %%
df['city'].nunique()
# Out:
# 7

# %%
df['city'].unique()
# Out:
# array(['Benin', 'Ekpoma', 'Auchi', 'Irrua', 'Igueben', 'Agenebode',
#        'Ogwa'], dtype=object)

# %%
df[['store_id', 'city']].drop_duplicates().sort_values('store_id')
# Out:
#      store_id       city
# 0           1      Benin
# 83          2     Ekpoma
# 240         3      Auchi
# 360         4      Irrua
# 480         5    Igueben
# 600         6  Agenebode
# 720         7       Ogwa

# %%
df_sales.product_id.nunique()
# Out:
# 120

# %%
product_store_counts = (
    df.groupby('product_id')['store_id']
      .nunique()
      .reset_index(name='n_stores')
      .sort_values('n_stores', ascending=False)
)

print(product_store_counts.head(10))
# Out:
#     product_id  n_stores
# 0         1001         7
# 1         1002         7
# 88        1089         7
# 87        1088         7
# 86        1087         7
# 85        1086         7
# 84        1085         7
# 83        1084         7
# 82        1083         7
# 81        1082         7

# %%
df[df['product_id'] == 1069][['product_id', 'store_id', 'city', 'category']].drop_duplicates().sort_values(['product_id', 'store_id'])
# Out:
#      product_id  store_id       city       category
# 1          1069         1      Benin  Mobile Phones
# 188        1069         2     Ekpoma  Mobile Phones
# 308        1069         3      Auchi  Mobile Phones
# 428        1069         4      Irrua  Mobile Phones
# 548        1069         5    Igueben  Mobile Phones
# 668        1069         6  Agenebode  Mobile Phones
# 823        1069         7       Ogwa  Mobile Phones

# %%
df_sales.columns
# Out:
# Index(['date', 'store_id', 'product_id', 'units_sold', 'price',
#        'regular_price', 'discount_pct', 'promo_flag', 'promo_type', 'revenue',
#        'starting_inventory', 'restock_qty', 'ending_inventory',
#        'stockout_occurred', 'restriction_active', 'restriction_type', 'city',
#        'store_size', 'store_type', 'category'],
#       dtype='object')

# %%
df_sales.discount_pct.value_counts()
# Out:
# discount_pct
# 0     1618678
# 15          2
# Name: count, dtype: int64

# %%
print(df[['store_id', 'city', 'store_size']].drop_duplicates().sort_values('store_id'))
# Out:
#      store_id       city store_size
# 0           1      Benin      Large
# 83          2     Ekpoma     Medium
# 240         3      Auchi     Medium
# 360         4      Irrua      Small
# 480         5    Igueben      Small
# 600         6  Agenebode      Small
# 720         7       Ogwa      Small

# %%
df_stores.head()
# Out:
#    store_id            store_name     city          area       region  \
# 0         1  SunnyBest Benin Main    Benin         Oredo    Edo South
# 1         2      SunnyBest Ekpoma   Ekpoma     Esan West  Edo Central
# 2         3       SunnyBest Auchi    Auchi   Etsako West    Edo North
# 3         4       SunnyBest Irrua    Irrua  Esan Central  Edo Central
# 4         5     SunnyBest Igueben  Igueben       Igueben  Edo Central
#
#     store_type store_size
# 0         Mall      Large
# 1  High Street     Medium
# 2  High Street     Medium
# 3        Plaza      Small
# 4  High Street      Small

# %%
df_stores
# Out:
#    store_id            store_name       city          area       region  \
# 0         1  SunnyBest Benin Main      Benin         Oredo    Edo South
# 1         2      SunnyBest Ekpoma     Ekpoma     Esan West  Edo Central
# 2         3       SunnyBest Auchi      Auchi   Etsako West    Edo North
# 3         4       SunnyBest Irrua      Irrua  Esan Central  Edo Central
# 4         5     SunnyBest Igueben    Igueben       Igueben  Edo Central
# 5         6   SunnyBest Agenebode  Agenebode   Etsako East    Edo North
# 6         7        SunnyBest Ogwa       Ogwa     Esan West  Edo Central
#
#     store_type store_size
# 0         Mall      Large
# 1  High Street     Medium
# 2  High Street     Medium
# 3        Plaza      Small
# 4  High Street      Small
# 5        Plaza      Small
# 6  High Street      Small

# %%
print(df_policy_regimes)
# Out:
#     policy_id                                policy_name           start_date  \
# 0           1                       Mall Expansion Drive  2021-04-10 00:00:00
# 1           3              Small Store Inventory Control  2022-01-11 00:00:00
# 2           2              Small Store Inventory Control           2022-11-06
# 3           2                      Telecom Seasonal Push  2024-11-09 00:00:00
# 4           1  Cooling Appliances Availability Programme           2024-11-19
# 5           4  Cooling Appliances Availability Programme  2025-07-09 00:00:00
# 6           3                      Telecom Seasonal Push           2025-09-10
# 7           4      Premium Electronics Margin Protection           2025-09-30
# 8           3  Cooling Appliances Availability Programme  2026-04-08 00:00:00
# 9           1                      Telecom Seasonal Push  2026-04-10 00:00:00
# 10          2      Premium Electronics Margin Protection  2026-04-10 00:00:00
# 11          4                       Mall Expansion Drive  2026-04-10 00:00:00
#
#                end_date affected_category affected_store_type  \
# 0   2021-12-04 00:00:00              None                Mall
# 1   2022-07-21 00:00:00              None               Plaza
# 2            2023-05-19              None               Plaza
# 3   2025-06-25 00:00:00  Telecom Services                None
# 4            2025-05-08  Air Conditioners                None
# 5   2025-10-20 00:00:00  Air Conditioners                None
# 6            2026-04-06  Telecom Services                None
# 7            2026-04-06     Mobile Phones                None
# 8   2026-04-11 00:00:00  Air Conditioners                None
# 9   2026-04-11 00:00:00  Telecom Services                None
# 10  2026-04-11 00:00:00     Mobile Phones                None
# 11  2026-04-11 00:00:00              None                Mall
#
#     demand_multiplier  discount_cap_pct  replenishment_multiplier  \
# 0                1.08                25                      1.12
# 1                0.98                15                      0.88
# 2                0.98                15                      0.88
# 3                1.15                20                      1.10
# 4                1.10                20                      1.20
# 5                1.10                20                      1.20
# 6                1.15                20                      1.10
# 7                0.96                10                      0.95
# 8                1.10                20                      1.20
# 9                1.15                20                      1.10
# 10               0.96                10                      0.95
# 11               1.08                25                      1.12
#
#     service_intensity_multiplier
# 0                           1.10
# 1                           1.00
# 2                           1.00
# 3                           1.08
# 4                           1.05
# 5                           1.05
# 6                           1.08
# 7                           1.02
# 8                           1.05
# 9                           1.08
# 10                          1.02
# 11                          1.10

# %%
df_products
# Out:
#      product_id                              product_name  \
# 0          1001                  LG Televisions Model-120
# 1          1002                    Tecno Mobile Model-199
# 2          1003                    Tecno Mobile Model-905
# 3          1004                  Infinix Mobile Model-121
# 4          1005                  Samsung Mobile Model-781
# 5          1006                  Infinix Mobile Model-786
# 6          1007                   Century Small Model-584
# 7          1008                  Binatone Small Model-415
# 8          1009                     Hisense Air Model-439
# 9          1010                    Acer Laptops Model-134
# 10         1011               Anker Accessories Model-489
# 11         1012                    Acer Laptops Model-829
# 12         1013             Samsung Televisions Model-915
# 13         1014                    Acer Laptops Model-819
# 14         1015                   Century Small Model-863
# 15         1016                  Binatone Small Model-164
# 16         1017                  Samsung Mobile Model-238
# 17         1018                    Tecno Mobile Model-589
# 18         1019                  LG Televisions Model-132
# 19         1020                     Itel Mobile Model-646
# 20         1021                LG Refrigerators Model-104
# 21         1022                   Panasonic Air Model-114
# 22         1023                  Infinix Mobile Model-340
# 23         1024                    Acer Laptops Model-848
# 24         1025                          LG Air Model-798
# 25         1026                   Philips Small Model-745
# 26         1027           Hisense Refrigerators Model-447
# 27         1028             Samsung Televisions Model-844
# 28         1029                  Lenovo Laptops Model-926
# 29         1030                      HP Laptops Model-541
# 30         1031                     Glo Telecom Model-724
# 31         1032                  Airtel Telecom Model-835
# 32         1033             Generic Accessories Model-515
# 33         1034                   Panasonic Air Model-866
# 34         1035                  Huawei Network Model-610
# 35         1036                  Samsung Mobile Model-563
# 36         1037                  Infinix Mobile Model-445
# 37         1038  Haier Thermocool Refrigerators Model-739
# 38         1039                LG Refrigerators Model-250
# 39         1040                     Hisense Air Model-723
# 40         1041                          LG Air Model-751
# 41         1042                   Panasonic Air Model-915
# 42         1043                     ZTE Network Model-724
# 43         1044                  Infinix Mobile Model-198
# 44         1045                     Glo Telecom Model-921
# 45         1046                  LG Televisions Model-497
# 46         1047                    Acer Laptops Model-294
# 47         1048                  Binatone Small Model-569
# 48         1049                    Asus Laptops Model-126
# 49         1050                     ZTE Network Model-552
# 50         1051                  Lenovo Laptops Model-271
# 51         1052              Oraimo Accessories Model-991
# 52         1053                     Itel Mobile Model-198
# 53         1054                 9mobile Telecom Model-260
# 54         1055                    Dell Laptops Model-669
# 55         1056               Anker Accessories Model-738
# 56         1057           Hisense Refrigerators Model-492
# 57         1058                   Century Small Model-966
# 58         1059                    Asus Laptops Model-135
# 59         1060                  Huawei Network Model-982
# 60         1061                    Acer Laptops Model-953
# 61         1062                    Dell Laptops Model-413
# 62         1063              Oraimo Accessories Model-543
# 92      Telecom Services               MTN          17837       12907
# 93         Mobile Phones              Itel         251415      154507
# 94      Small Appliances          Binatone          37556       23170
# 95           Televisions                LG         318067      205896
# 96      Air Conditioners           Hisense         844699      520925
# 97      Air Conditioners         Panasonic         548345      365225
# 98   Laptops & Computers              Dell         814795      582003
# 99      Small Appliances          Binatone          54298       38913
# 100          Televisions                LG         628248      486087
# 101     Telecom Services           9mobile          13472       10696
# 102          Accessories             Anker          32860       26241
# 103     Air Conditioners                LG         738353      467556
# 104  Laptops & Computers                HP         651108      481419
# 105     Small Appliances           Century          28323       22424
# 106     Small Appliances           Philips          61427       44802
# 107     Air Conditioners                LG         227016      148012
# 108        Mobile Phones           Samsung         410896      280330
# 109  Laptops & Computers              Asus         315421      194059
# 110          Televisions                LG         655278      513630
# 111          Accessories           Generic          34548       21867
# 112      Network Devices           TP-Link          82292       61712
# 113      Network Devices            Huawei          66540       40769
# 114        Mobile Phones              Itel         504159      310093
# 115     Telecom Services               Glo          15606       11097
# 116          Accessories             Anker          18456       11963
# 117  Laptops & Computers              Asus         696237      540032
# 118  Laptops & Computers              Dell         658153      463380
# 119        Refrigerators                LG         740053      587302
#
#      is_seasonal  warranty_months
# 0              1                6
# 1              1                6
# 2              1               12
# 3              1               12
# 4              1               24
# 5              1               12
# 6              0               24
# 7              0                6
# 8              1               12
# 9              0               24
# 10             0               12
# 11             0               12
# 12             1               24
# 13             0                6
# 14             0                6
# 15             0                6
# 16             1               24
# 17             1                6
# 18             1               12
# 19             1               24
# 20             1                6
# 21             1               24
# 22             1               24
# 23             0               24
# 24             1               24
# 25             0                6
# 26             1               24
# 27             1                6
# 28             0               24
# 29             0                6
# 30             1                6
# 31             1               24
# 32             0               12
# 33             1                6
# 34             0               12
# 35             1               12
# 36             1               24
# 37             1                6
# 38             1                6
# 39             1               12
# 40             1               12
# 41             1               24
# 42             0               24
# 43             1                6
# 44             1               12
# 45             1                6
# 46             0               24
# 47             0               24
# 48             0               24
# 49             0                6
# 50             0                6
# 51             0               24
# 52             1               24
# 53             1               24
# 54             0               12
# 55             0               24
# 56             1                6
# 57             0               12
# 58             0                6
# 59             0               12
# 60             0               24
# 61             0               12
# 62             0               12
# 63             0                6
# 64             1               24
# 65             0               12
# 66             0               24
# 67             1                6
# 68             1               12
# 69             0                6
# 70             1               12
# 71             1                6
# 72             1               12
# 73             1               12
# 74             1               24
# 75             0               24
# 76             1               12
# 77             0                6
# 78             1                6
# 79             0               24
# 80             1               12
# 81             0                6
# 82             0               12
# 83             0               12
# 84             0                6
# 85             0               12
# 86             0                6
# 87             0               24
# 88             1                6
# 89             0               24
# 90             0               24
# 91             1               24
# 92             1                6
# 93             1               12
# 94             0               24
# 95             1               24
# 96             1                6
# 97             1               12
# 98             0                6
# 99             0               12
# 100            1               12
# 101            1                6
# 102            0                6
# 103            1                6
# 104            0               24
# 105            0               12
# 106            0               12
# 107            1               24
# 108            1                6
# 109            0               12
# 110            1               12
# 111            0                6
# 112            0                6
# 113            0                6
# 114            1                6
# 115            1                6
# 116            0                6
# 117            0               12
# 118            0               12
# 119            1               12
