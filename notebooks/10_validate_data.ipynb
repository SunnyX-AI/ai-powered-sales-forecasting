# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plot settings
plt.rcParams["figure.figsize"] = (12, 6)
sns.set(style="whitegrid")

DATA_DIR = "../data/raw"

sales = pd.read_csv(f"{DATA_DIR}/sunnybest_sales.csv", parse_dates=["date"])
inventory = pd.read_csv(f"{DATA_DIR}/sunnybest_inventory.csv", parse_dates=["date"])
customer_activity = pd.read_csv(f"{DATA_DIR}/sunnybest_customer_activity.csv", parse_dates=["date"])
store_operations = pd.read_csv(f"{DATA_DIR}/sunnybest_store_operations.csv", parse_dates=["date"])
policy_regimes = pd.read_csv(f"{DATA_DIR}/sunnybest_policy_regimes.csv", parse_dates=["start_date", "end_date"])
restriction_events = pd.read_csv(f"{DATA_DIR}/sunnybest_restriction_events.csv", parse_dates=["date"])

for name, df in {
    "sales": sales,
    "inventory": inventory,
    "customer_activity": customer_activity,
    "store_operations": store_operations,
    "policy_regimes": policy_regimes,
    "restriction_events": restriction_events,
}.items():
    print(f"\n{name.upper()}")
    print(df.shape)
    print(df.isna().sum().sort_values(ascending=False).head(10))
    print(df.head())
# Out:
# /var/folders/rt/0zxshr9s4g713_r6y5sjpqk80000gn/T/ipykernel_44864/1299198541.py:11: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv(f"{DATA_DIR}/sunnybest_sales.csv", parse_dates=["date"])
# SALES
# (1227240, 20)
# promo_type            1226951
# restriction_type      1145575
# date                        0
# restock_qty                 0
# store_type                  0
# store_size                  0
# city                        0
# restriction_active          0
# stockout_occurred           0
# ending_inventory            0
# dtype: int64
#         date  store_id  product_id  units_sold     price  regular_price  \
# 0 2021-01-01         1        1001           2  445838.0         445838
# 1 2021-01-01         1        1002           3  500410.0         500410
# 2 2021-01-01         1        1003           4  399365.0         399365
# 3 2021-01-01         1        1004           1  305796.0         305796
# 4 2021-01-01         1        1005           2  462752.0         462752
#
#    discount_pct  promo_flag promo_type    revenue  starting_inventory  \
# 0             0           0        NaN   891676.0                  10
# 1             0           0        NaN  1501230.0                   9
# 2             0           0        NaN  1597460.0                  18
# 3             0           0        NaN   305796.0                   9
# 4             0           0        NaN   925504.0                   6
#
#    restock_qty  ending_inventory  stockout_occurred  restriction_active  \
# 0            0                 8                  0                   0
# 1            0                 6                  0                   0
# 2            0                14                  0                   0
# 3            0                 8                  0                   1
# 4            0                 4                  0                   0
#
#   restriction_type   city store_size store_type       category
# 0              NaN  Benin      Large       Mall    Televisions
# 1              NaN  Benin      Large       Mall  Mobile Phones
# 2              NaN  Benin      Large       Mall  Mobile Phones
# 3     Supply Delay  Benin      Large       Mall  Mobile Phones
# 4              NaN  Benin      Large       Mall  Mobile Phones
#
# INVENTORY
# (1227240, 7)
# date                  0
# store_id              0
# product_id            0
# starting_inventory    0
# restock_qty           0
# ending_inventory      0
# stockout_flag         0
# dtype: int64
#         date  store_id  product_id  starting_inventory  restock_qty  \
# 0 2021-01-01         1        1001                  10            0
# 1 2021-01-01         1        1002                   9            0
# 2 2021-01-01         1        1003                  18            0
# 3 2021-01-01         1        1004                   9            0
# 4 2021-01-01         1        1005                   6            0
#
#    ending_inventory  stockout_flag
# 0                 8              0
# 1                 6              0
# 2                14              0
# 3                 8              0
# 4                 4              0
#
# CUSTOMER_ACTIVITY
# (10227, 9)
# date                         0
# store_id                     0
# active_customers             0
# new_customers                0
# returning_customers          0
# churn_risk_customers         0
# net_customer_change          0
# estimated_conversion_rate    0
# daily_revenue                0
# dtype: int64
#         date  store_id  active_customers  new_customers  returning_customers  \
# 0 2021-01-01         1               371             69                  302
# 1 2021-01-01         2               285             72                  213
# 2 2021-01-01         3               313             56                  257
# 3 2021-01-01         4               211             25                  186
# 4 2021-01-01         5               292             55                  237
#
#    churn_risk_customers  net_customer_change  estimated_conversion_rate  \
# 0                     0                    0                      1.437
# 1                     0                    0                      1.495
# 2                     0                    0                      1.054
# 3                     0                    0                      1.711
# 4                     0                    0                      1.110
#
#    daily_revenue
# 0     58470174.0
# 1     42561566.0
# 2     49956070.0
# 3     36997019.0
# 4     39320692.0
#
# STORE_OPERATIONS
# (10227, 8)
# date                      0
# store_id                  0
# staff_on_duty             0
# customer_visits           0
# support_requests          0
# completed_interactions    0
# missed_interactions       0
# service_pressure_score    0
# dtype: int64
#         date  store_id  staff_on_duty  customer_visits  support_requests  \
# 0 2021-01-01         1             22              371                58
# 1 2021-01-01         2             12              285                23
# 2 2021-01-01         3              7              313                25
# 3 2021-01-01         4              6              211                35
# 4 2021-01-01         5              3              292                39
#
#    completed_interactions  missed_interactions  service_pressure_score
# 0                      54                    4                   19.50
# 1                      21                    2                   25.67
# 2                      22                    3                   48.29
# 3                      32                    3                   41.00
# 4                      36                    3                  110.33
#
# POLICY_REGIMES
# (4, 10)
# affected_category               2
# affected_store_type             2
# policy_id                       0
# policy_name                     0
# start_date                      0
# end_date                        0
# demand_multiplier               0
# discount_cap_pct                0
# replenishment_multiplier        0
# service_intensity_multiplier    0
# dtype: int64
#    policy_id                                policy_name start_date   end_date  \
# 0          1  Cooling Appliances Availability Programme 2023-10-17 2024-03-14
# 1          2              Small Store Inventory Control 2022-01-03 2022-05-15
# 2          3                       Mall Expansion Drive 2022-08-28 2022-12-25
# 3          4                      Telecom Seasonal Push 2023-12-23 2024-04-14
#
#   affected_category affected_store_type  demand_multiplier  discount_cap_pct  \
# 0  Air Conditioners                 NaN               1.10                20
# 1               NaN               Plaza               0.98                15
# 2               NaN                Mall               1.08                25
# 3  Telecom Services                 NaN               1.15                20
#
#    replenishment_multiplier  service_intensity_multiplier
# 0                      1.20                          1.05
# 1                      0.88                          1.00
# 2                      1.12                          1.10
# 3                      1.10                          1.08
#
# RESTRICTION_EVENTS
# (16340, 8)
# date                    0
# store_id                0
# product_id              0
# restriction_type        0
# restriction_reason      0
# restriction_severity    0
# duration_days           0
# active_flag             0
# dtype: int64
#         date  store_id  product_id  restriction_type      restriction_reason  \
# 0 2021-01-01         1        1004      Supply Delay     Replenishment delay
# 1 2021-01-01         1        1090  Promo Suspension  Margin protection rule
# 2 2021-01-01         2        1067      Supply Delay     Replenishment delay
# 3 2021-01-01         2        1070      Supply Delay     Replenishment delay
# 4 2021-01-01         2        1086      Supply Delay     Replenishment delay
#
#   restriction_severity  duration_days  active_flag
# 0                  Low              3            1
# 1               Medium              5            1
# 2               Medium              4            1
# 3                 High              5            1
# 4               Medium              2            1

# %%
policy_regimes
# Out:
#    policy_id                                policy_name start_date   end_date  \
# 0          1  Cooling Appliances Availability Programme 2023-10-17 2024-03-14
# 1          2              Small Store Inventory Control 2022-01-03 2022-05-15
# 2          3                       Mall Expansion Drive 2022-08-28 2022-12-25
# 3          4                      Telecom Seasonal Push 2023-12-23 2024-04-14
#
#   affected_category affected_store_type  demand_multiplier  discount_cap_pct  \
# 0  Air Conditioners                 NaN               1.10                20
# 1               NaN               Plaza               0.98                15
# 2               NaN                Mall               1.08                25
# 3  Telecom Services                 NaN               1.15                20
#
#    replenishment_multiplier  service_intensity_multiplier
# 0                      1.20                          1.05
# 1                      0.88                          1.00
# 2                      1.12                          1.10
# 3                      1.10                          1.08
