# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot settings
plt.rcParams["figure.figsize"] = (12, 6)
sns.set(style="whitegrid")

DATA_DIR = "../data/raw"

# %%
import pandas as pd
# Plot settings
plt.rcParams["figure.figsize"] = (12, 6)
sns.set(style="whitegrid")

DATA_DIR = "../data/raw"
sales = pd.read_csv(f"{DATA_DIR}/sunnybest_sales.csv", parse_dates=["date"])
inventory = pd.read_csv(f"{DATA_DIR}/sunnybest_inventory.csv", parse_dates=["date"])
customer_activity = pd.read_csv(f"{DATA_DIR}/sunnybest_customer_activity.csv", parse_dates=["date"])
store_operations = pd.read_csv(f"{DATA_DIR}/sunnybest_store_operations.csv", parse_dates=["date"])
policy_regimes = pd.read_csv(f"{DATA_DIR}/sunnybest_policy_regimes.csv", parse_dates=["start_date", "end_date"])
restriction_events = pd.read_csv(f"{DATA_DIR}/sunnybest_restriction_events.csv", parse_dates=["date"])

for name, df in {
    "sales": sales_df,
    "inventory": inventory_df,
    "customer_activity": customer_activity_df,
    "store_operations": store_operations_df,
    "policy_regimes": policy_regimes_df,
    "restriction_events": restriction_events_df,
}.items():
    print(f"\n{name.upper()}")
    print(df.shape)
    print(df.isna().sum().sort_values(ascending=False).head(10))
    print(df.head())
# Out:
# /var/folders/rt/0zxshr9s4g713_r6y5sjpqk80000gn/T/ipykernel_44864/8035676.py:7: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv(f"{DATA_DIR}/sunnybest_sales.csv", parse_dates=["date"])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      11 policy_regimes = pd.read_csv(f"{DATA_DIR}/sunnybest_policy_regimes.csv", parse_dates=["start_date", "end_date"])
#      12 restriction_events = pd.read_csv(f"{DATA_DIR}/sunnybest_restriction_events.csv", parse_dates=["date"])
#      14 for name, df in {
# ---> 15     "sales": sales_df,
#      16     "inventory": inventory_df,
#      17     "customer_activity": customer_activity_df,
#      18     "store_operations": store_operations_df,
#      19     "policy_regimes": policy_regimes_df,
# ...
