# %%
import pandas as pd
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus

host = "aws-1-eu-central-1.pooler.supabase.com"
port = 5432
database = "postgres"
user = "sfs_user.ogkdfmkybqtrsglcizzt"
password = quote_plus("Chinenyennabude123")  # rotate the old one first

engine = create_engine(
    f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}?sslmode=require",
    pool_pre_ping=True
)

with engine.connect() as conn:
    df = pd.read_sql(
        text("SELECT * FROM core.fact_sales LIMIT 200"),
        conn
    )

print(df.head())
# Out:
#          date  store_id  product_id  units_sold     price  regular_price  \
# 0  2024-12-18         1        1084           0  103042.0         103042
# 1  2024-12-18         1        1084           0  103042.0         103042
# 2  2024-12-18         1        1085           0  456955.0         456955
# 3  2024-12-18         1        1085           0  456955.0         456955
# 4  2024-12-18         1        1086           0   75069.0          75069
#
#    discount_pct  promo_flag promo_type  revenue  starting_inventory  \
# 0             0           0       None      0.0                   0
# 1             0           0       None      0.0                   0
# 2             0           0       None      0.0                   0
# 3             0           0       None      0.0                   0
# 4             0           0       None      0.0                   0
#
#    restock_qty  ending_inventory  stockout_occurred  restriction_active  \
# ...

# %%
df.shape
# Out:
# (200, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       5 non-null      object
#  1   store_id                   5 non-null      int64
#  2   active_customers           5 non-null      int64
#  3   new_customers              5 non-null      int64
#  4   returning_customers        5 non-null      int64
#  5   churn_risk_customers       5 non-null      int64
#  6   net_customer_change        5 non-null      int64
#  7   estimated_conversion_rate  5 non-null      float64
#  8   daily_revenue              5 non-null      float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 488.0+ bytes
